# %%
import numpy as np

# %% [markdown]
# ### Задача 1
#
# Рассмотрим пример 2 из методички. Чтобы посчитать вероятность такого события, нужно использовать сочетания или размещения? Ответ необходимо обосновать.

# %% [markdown]
# >Пример 2
# >
# >Еще один пример дискретной случайной величины — число дождливых дней летом.
# >
# >Летних дней всего 92, так что здесь мы можем получить случайное целое число из отрезка [0, 92]:

# %% [markdown]
# #### Решение

# %% [markdown]
# Чтобы посчитать вероятность такого события необходимо использовать сочетание, т.к. порядок в котором будут случаться дождливые дни не важен. Важно их количество за лето.

# %% [markdown]
# #### Ответ

# %% [markdown]
# сочетание

# %% [markdown]
# ### Задача 2
#
# Группа студентов изучает 10 различных дисциплин. Сколькими способами можно составить расписание на понедельник, если в этот день должно быть 4 разных занятия?

# %% [markdown]
# #### Решение

# %% [markdown]
# Для решения посчитаем количество размещений 4 уроков из 10 дисциплин, т.к. порядок уроков важен.

# %%
def arrangements(n, k):
    return np.math.factorial(n) // np.math.factorial(n - k)


answer = arrangements(10, 4)

# %% [markdown]
# #### Ответ

# %%
print(f'Расписание на понедельник можно составить {answer} способами')
# Out:
# Расписание на понедельник можно составить 5040 способами

# %% [markdown]
# ### Задача 3
#
# Семь человек рассаживаются наудачу на скамейке. Какова вероятность того, что два определённых человека будут сидеть рядом?

# %% [markdown]
# #### Решение

# %% [markdown]
# Вероятность такого события будет равна отношениию успешных событий ко всей совокупности событий. Всего возможно 12 вариантов того, что два определенных человека окажутся рядом плюс перестановка из 5 оставшихся людей. А для расчета всех вариантов размещения 7 человек на скамейке воспользуемся формулой перестановки из 7 элементов.

# %%
def permutations(n):
    return np.math.factorial(n)


m = 12 * permutations(5)
n = permutations(7)

P = m / n

# %% [markdown]
# #### Ответ

# %%
print(f'Вероятность того, что два определённых человека будут сидеть рядом равна {round(P*100, 2)}%')
# Out:
# Вероятность того, что два определённых человека будут сидеть рядом равна 28.57%

# %% [markdown]
# ### Задача 4
#
# Из 60 вопросов, входящих в экзаменационные билеты, студент знает 50. Какова вероятность того, что среди трёх наугад выбранных вопросов студент знает: а) все? б) два?

# %% [markdown]
# #### Решение

# %% [markdown]
# Чтобы узнать количество вариантов которыми можно вытащить 3 билета воспользуемся формулой сочетания 3 из 60 элементов. Количество вариантов когда студент вытаскивает 3 выученных билета равна количеству сочетаний 3 элементов из 50. А количество вариантов вытащить 2 выученных билета и один не выученный равнв произведению сочетаний 2 из 50 и 1 из 10.
#
# Вероятность событий будем считать по формуле P(A) = m / n

# %%
P_a = combinations(50, 3) / combinations(60, 3)
P_b = (combinations(50, 2) * 10) / combinations(60, 3)

# %% [markdown]
# #### Ответ

# %%
print(f'a) {round(P_a*100, 2)}%')
print(f'б) {round(P_b*100, 2)}%')
# Out:
# a) 57.28%
# б) 35.8%

# %% [markdown]
# ### Задача 5
#
# Бросается игральная кость. Пусть событие A - появление чётного числа, событие B - появление числа больше трёх. Являются ли эти события независимыми?

# %% [markdown]
# #### Решение

# %% [markdown]
# События 𝐴 и 𝐵 называются независимыми, если 𝑃(𝐵|𝐴)=𝑃(𝐵). Где P(B|A)=𝑃(𝐴𝐵)/𝑃(𝐴). В нашем случае P(AB) раво 1/3, т.к. условию выпадения четного числа больше 3 удолетворяют события выпадения числа 4 и 6. Вероятность P(A)=1/2, вероятность P(B)=1/2.
#
# P(B|A)=𝑃(𝐴𝐵)/𝑃(𝐴) = 1/3 / 1/2 = 2/3
#
# 𝑃(𝐵|𝐴) != 𝑃(𝐵), т.к. 2/3 != 1/2

# %% [markdown]
# #### Ответ

# %% [markdown]
# События не являются независимыми.

# %% [markdown]
# ### Задача 6
#
# Допустим, имеется некоторая очень редкая болезнь (поражает 0.1% населения). Вы приходите к врачу, вам делают тест на эту болезнь, и тест оказывается положительным. Врач говорит вам, что этот тест верно выявляет 99 % больных этой болезнью и всего лишь в 1% случаев даёт ложный положительный ответ.
#
# Вопрос: вакова вероятность, что вы действительно больны ей?
#
# Подсказка: используйте формулу Байеса с раскрытием знаменателя с помощью формулы полной вероятности.

# %% [markdown]
# #### Решение

# %% [markdown]
# Пусть событие A - тест оказался положительным. Событие B - я оказался болен. Тогда вероятность того, что я действительно болен при положительном результате теста будем считать по формуле Байеса.
#
# P(B|A) = (P(A|B) * P(B)) / P(A)
#
# где:
# P(A|B) это вероятность положительного теста при условии что я болен, она равна 0.99 по условию задачи
# P(B) равна 0.001 так же по условию задачи
# P(A) распишем по формуле полной вероятности. У нас есть две гипотезы: H1 - тест верно показал результат, H2 - тест ложно положительный.
#
# Тогда P(A) = P(H1) * P(A|H1) + P(H2) * P(A|H2).
#
# Где P(H1) = 0.99, P(H2) = 0.01, P(A|H1) = 0.001 (0.1% населения), P(A|H2) = 0.999 (99.9% населения)
#
# Подставим значения в формулу:
#
# P(B|A) = (0.99 * 0.001) / (0.99 * 0.001 + 0.01 * 0.999)

# %%
P_ba = (0.99 * 0.001) / (0.99 * 0.001 + 0.01 * 0.999)

# %% [markdown]
# #### Ответ

# %%
print(f'Вероятность того, что я действительно болен равна {round(P_ba*100, 2)}%')
# Out:
# Вероятность того, что я действительно болен равна 9.02%
